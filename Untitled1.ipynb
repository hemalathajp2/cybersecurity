# %% [markdown]
# <a href="https://colab.research.google.com/github/hemalathajp2/cybersecurity/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = np.random.randint(1,10,8).tolist()

# %%
a
# Out:
# [6, 2, 8, 8, 7, 6, 1, 7]

# %%
a=np.random.randint(1,10,8).tolist()
scalar=5
result=scalar *a

# %%
print(a)
print(result)
# Out:
# [8, 6, 9, 8, 8, 9, 3, 1]
# [8, 6, 9, 8, 8, 9, 3, 1, 8, 6, 9, 8, 8, 9, 3, 1, 8, 6, 9, 8, 8, 9, 3, 1, 8, 6, 9, 8, 8, 9, 3, 1, 8, 6, 9, 8, 8, 9, 3, 1]

# %%
a=np.random.randint(1,10,8).tolist()
scalar=5
result=[X * scalar for X in a]

# %%
print(a)
print(result)
# Out:
# [2, 3, 4, 5, 7, 4, 5, 2]
# [10, 15, 20, 25, 35, 20, 25, 10]

# %%
a=np.random.randint(1,10,8).tolist()
scalar=5
result=[X * scalar for X in a]

# %%
import numpy as np

a = np.random.randint(1, 10, 10)
b = np.random.randint(1, 10, 10)

result = a * b

print("A:", a)
print("B:", b)
print("Result:", result)
# Out:
# A: [5 5 2 7 5 4 8 1 9 9]
# B: [9 7 2 7 8 2 8 7 4 2]
# Result: [45 35  4 49 40  8 64  7 36 18]

# %%
a = np.random.randint(1, 10, 10)
b = np.random.randint(1, 10, 10)

# %%
print(a)
print(b)
# Out:
# [1 3 5 1 2 6 2 6 6 3]
# [1 5 8 9 3 4 6 2 9 4]

# %%
[a[i] * b[i] for i in range(len(a))]
# Out:
# [np.int64(1),
#  np.int64(15),
#  np.int64(40),
#  np.int64(9),
#  np.int64(6),
#  np.int64(24),
#  np.int64(12),
#  np.int64(12),
#  np.int64(54),
#  np.int64(12)]

# %%
len(a)
# Out:
# 10

# %%
a = np.random.randint(1,10,5).tolist()
b = np.random.randint(1,10,5).tolist()
print(a)
print(b)
# Out:
# [8, 2, 2, 5, 8]
# [7, 1, 3, 4, 5]

# %%
result=0
for i in range (len(a)):
  result += a[i] * b[i]
print(" dot product result",result)
# Out:
#  dot product result 124

# %%
A = [[1,2,3],[4,5,6],[7,8,9]]
B = [[9,8,7],[6,5,4],[3,2,1]]

C = [[0]*3 for _ in range(3)]

for i in range(3):
    for j in range(3):
        C[i][j] = A[i][0]*B[0][j] + A[i][1]*B[1][j] + A[i][2]*B[2][j]

for row in C:
    print(row)
# Out:
# [30, 24, 18]
# [84, 69, 54]
# [138, 114, 90]

# %%
A = np.random.randint(1,10, (3,3))
B = np.random.randint(1,10, (3,3))
print(A)
print(B)
# Out:
# [[6 2 4]
#  [4 8 2]
#  [8 4 6]]
# [[7 4 5]
#  [6 8 1]
#  [8 5 4]]

# %%
result = [[ 0 for   _ in    range(3)] for  _ in range(3)]
for i in range(3) :
  for j in range(3) :
    for k in range(3) :
      result[i][j] +=A[i][k] * B[k][j]
      for row in result :
         print(row)
      print (result)
    print(A[i][j] * B[i][j] , end=" ")
  print()
# Out:
# [np.int64(42), 0, 0]
# [0, 0, 0]
# [0, 0, 0]
# [[np.int64(42), 0, 0], [0, 0, 0], [0, 0, 0]]
# [np.int64(54), 0, 0]
# [0, 0, 0]
# [0, 0, 0]
# [[np.int64(54), 0, 0], [0, 0, 0], [0, 0, 0]]
# [np.int64(86), 0, 0]
# [0, 0, 0]
# [0, 0, 0]
# [[np.int64(86), 0, 0], [0, 0, 0], [0, 0, 0]]
# 42 [np.int64(86), np.int64(24), 0]
# [0, 0, 0]
# [0, 0, 0]
# [[np.int64(86), np.int64(24), 0], [0, 0, 0], [0, 0, 0]]
# [np.int64(86), np.int64(40), 0]
# [0, 0, 0]
# [0, 0, 0]
# [[np.int64(86), np.int64(40), 0], [0, 0, 0], [0, 0, 0]]
# [np.int64(86), np.int64(60), 0]
# [0, 0, 0]
# [0, 0, 0]
# [[np.int64(86), np.int64(60), 0], [0, 0, 0], [0, 0, 0]]
# 8 [np.int64(86), np.int64(60), np.int64(30)]
# [0, 0, 0]
# [0, 0, 0]
# [[np.int64(86), np.int64(60), np.int64(30)], [0, 0, 0], [0, 0, 0]]
# [np.int64(86), np.int64(60), np.int64(32)]
# [0, 0, 0]
# [0, 0, 0]
# [[np.int64(86), np.int64(60), np.int64(32)], [0, 0, 0], [0, 0, 0]]
# [np.int64(86), np.int64(60), np.int64(48)]
# [0, 0, 0]
# [0, 0, 0]
# ...

# %%
A @ B
# Out:
# array([[ 86,  60,  48],
#        [ 92,  90,  36],
#        [128,  94,  68]])

# %%
# Given x values
x = [1, 2, 3, 4, 5]

# Construct the matrix
matrix = [[i**2, i, 1] for i in x]

# Print the matrix
for row in matrix:
    print(row)
# Out:
# [1, 1, 1]
# [4, 2, 1]
# [9, 3, 1]
# [16, 4, 1]
# [25, 5, 1]

# %%
x = np.array([1,2,3])
x = np.vstack((x**2, x, np.ones(len(x)))).T

# %%
x
# Out:
# array([[1., 1., 1.],
#        [4., 2., 1.],
#        [9., 3., 1.]])

# %%
def calculate_y(x):
  return x**2 -2*x + 5

# %%
calculate_y(3)
# Out:
# 8

# %%
noise = np.random.normal(0,1,10)

# %%
plt.plot(noise, marker = 'o')
plt.show()

# %%
a = np.arange(-1,1,0.1)
b = np.arange(-1,1,0.1)
A, B = np.meshgrid(a,b)
plt.plot(A,B, 'k.' , markersize=1)
plt.show()

# %%
list_values = np.random.uniform (-10,10,400).tolist()

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(A, B, np.array(list_values).reshape(A.shape),cmap='viridis')
plt.show()

# %%
def calculate_y(x):
  return x**2 -2*x + 5

# %%
x=np.linspace(-10,10,100)
y_actual =calculate_y(x)

# %%
noise = np.random.normal(0,1,100)
y_noisy = y_actual + noise

# %%
x_vals = np.arange(-10, 10, 0.2)
y_vals = calculate_y(x_vals)

# %%
plt.plot(x_vals,y_vals, color='black')
plt.scatter(x,y_noisy, color='red')
plt.show()

# %% [markdown]
# quadratic model over a grid  of parameters

# %% [markdown]
# Question 1 Generate a set of noisy points around a quadratic curve defined by the function y = ax^2 + bx + c, where a=1, b=-2, and c=5. Choose 100 values for x uniformly spaced in the interval from -10 to 10. For each value of x, compute the corresponding y by adding Gaussian noise with zero mean and unit variance to the curve values. Plot both the original quadratic curve (without noise) in black and the noisy data

# %% [markdown]
# Question 2: Analyze the error surface of the quadratic model over a grid of parameters a and b, while keeping fixed c = 5. Let both a and b vary from -10 to 10 in steps of 0.1. For each pair of a and b, compute the prediced values of y, and calculate the average squared error between the predicted values and the noisy values obtaied in Question1. Plot the error surface with a on the x-axis, b on the y-axis and the average error on the z-axis.

# %%
import numpy as np
import matplotlib.pyplot as plt

# --------------------------------------------------
# Example data (ONLY use if Question 1 data not given)
# --------------------------------------------------
# np.random.seed(0)
# x = np.linspace(-5, 5, 50)
# true_a, true_b, true_c = 2, -3, 5
# y_noisy = true_a*x**2 + true_b*x + true_c + np.random.normal(0, 5, len(x))

# --------------------------------------------------
# Given from Question 1
# --------------------------------------------------
# x = ...
# y_noisy = ...

c = 5

# Parameter grid
a_vals = np.arange(-10, 10, 0.1)
b_vals = np.arange(-10, 10, 0.1)

A, B = np.meshgrid(a_vals, b_vals)
error_surface = np.zeros(A.shape)

# Compute average squared error
for i in range(len(a_vals)):
    for j in range(len(b_vals)):
        y_pred = A[j, i] * x**2 + B[j, i] * x + c
        error_surface[j, i] = np.mean((y_noisy - y_pred) ** 2)

# --------------------------------------------------
# Plot the error surface
# --------------------------------------------------
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(A, B, error_surface, cmap='viridis')

ax.set_xlabel('a')
ax.set_ylabel('b')
ax.set_zlabel('Average Squared Error')
ax.set_title('Error Surface of Quadratic Model')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------
# Question 1: Generate noisy data
# -------------------------------
a_true = 1
b_true = -2
c = 5

# Generate x values
x = np.linspace(-10, 10, 100)

# True quadratic curve
y_true = a_true * x**2 + b_true * x + c

# Add Gaussian noise (mean=0, variance=1)
noise = np.random.normal(0, 1, size=len(x))
y_noisy = y_true + noise

# Plot true curve and noisy data
plt.figure(figsize=(8, 5))
plt.plot(x, y_true, 'k', label='True quadratic curve')
plt.scatter(x, y_noisy, color='red', s=15, label='Noisy data')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Quadratic Curve with Noisy Data')
plt.legend()
plt.show()


# -----------------------------------------
# Question 2: Error surface for parameters

# %%
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------------
# Step 1: Generate the dataset
# -----------------------------------
np.random.seed(42)   # fixed random seed

mean = np.array([2, -1])
cov = np.array([[3, 2],
                [2, 2]])

# Generate 200 samples
X = np.random.multivariate_normal(mean, cov, 200)

# -----------------------------------
# Step 2: Plot raw samples & empirical mean
# -----------------------------------
empirical_mean = np.mean(X, axis=0)

plt.figure(figsize=(6, 6))
plt.scatter(X[:, 0], X[:, 1], alpha=0.6, label='Samples')
plt.scatter(empirical_mean[0], empirical_mean[1],
            color='red', marker='x', s=100, label='Empirical Mean')

plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Raw Samples from Multivariate Gaussian')
plt.legend()
plt.axis('equal')
plt.grid(True)
plt.show()

# -----------------------------------
# Step 3: Center the data
# -----------------------------------
X_centered = X - empirical_mean

# -----------------------------------
# Step 4: Compute covariance matrix
# -----------------------------------
cov_matrix = np.cov(X_centered, rowvar=False)

print("Empirical Covariance Matrix:\n", cov_matrix)

# -----------------------------------
# Step 5: Eigenvalues & Eigenvectors (PCA)
# -----------------------------------
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# Sort eigenvalues (descending) and eigenvectors
idx = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[idx]
eigenvectors = eigenvectors[:, idx]

print("\nEigenvalues:\n", eigenvalues)
print("\nEigenvectors:\n", eigenvectors)

# Principal components
pc1 = eigenvectors[:, 0]  # First principal component
pc2 = eigenvectors[:, 1]  # Second principal component

print("\nFirst Principal Component:\n", pc1)
print("\nSecond Principal Component:\n", pc2)

# -----------------------------------
# Optional: Plot principal components
# -----------------------------------
plt.figure(figsize=(6, 6))
plt.scatter(X_centered[:, 0], X_centered[:, 1], alpha=0.5)

origin = np.zeros(2)
plt.quiver(*origin, pc1[0], pc1[1], color='r',
           scale=3, width=0.01, label='PC1')
plt.quiver(*origin, pc2[0], pc2[1], color='g',
           scale=3, width=0.01, label='PC2')

plt.xlabel('Centered X1')
plt.ylabel('Centered X2')
plt.title('Principal Components')
plt.legend()
plt.axis('equal')
plt.grid(True)
plt.show()
# Out:
# Empirical Covariance Matrix:
#  [[2.7186379  1.84079041]
#  [1.84079041 1.87427921]]
#
# Eigenvalues:
#  [4.18504129 0.40787583]
#
# Eigenvectors:
#  [[ 0.78215821 -0.62307987]
#  [ 0.62307987  0.78215821]]
#
# First Principal Component:
#  [0.78215821 0.62307987]
#
# Second Principal Component:
#  [-0.62307987  0.78215821]
